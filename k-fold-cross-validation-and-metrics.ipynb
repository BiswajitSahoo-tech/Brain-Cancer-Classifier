# %%
import os
import PIL
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from PIL import Image
from sklearn.model_selection import KFold
from tensorflow import keras

# %%
# Define the number of folds
num_folds = 5

# Define the data directory and batch size
data_dir = '/kaggle/input/preprocessed-brain-mri-images/brain-tumor/processed-images'
batch_size = 32
img_height = 224
img_width = 224

# %%
# Create a list to store the file paths and labels
data = []
labels = []

# Iterate over the subdirectories in the data directory
for subdir in os.listdir(data_dir):
    # Get the full path of the subdirectory
    subdir_path = os.path.join(data_dir, subdir)

    # Check if the subdirectory is a directory
    if os.path.isdir(subdir_path):
        # Iterate over the files in the subdirectory
        for filename in os.listdir(subdir_path):
            # Get the full path of the file
            file_path = os.path.join(subdir_path, filename)

            # Check if the file is an image
            if file_path.endswith('.jpg') or file_path.endswith('.png'):
                # Add the file path and label to the lists
                data.append(file_path)
                labels.append(subdir)

# %%
print(len(data))
print(len(labels))
# Out:
# 12256
# 12256

# %%
# Create a DataFrame from the lists
df = pd.DataFrame({'filename': data, 'class': labels})

# %%
# Create a data generator for loading images in batches
datagen = keras.preprocessing.image.ImageDataGenerator()

# # Load the data using the data generator
# data = datagen.flow_from_dataframe(
#     df,
#     x_col='filename',
#     y_col='class',
#     target_size=(img_height, img_width),
#     batch_size=batch_size,
#     class_mode='categorical'
# )

# %%
# Define the k-fold cross-validator
kfold = KFold(n_splits=num_folds, shuffle=True)

# Define a list to store the accuracy scores for each fold
acc_per_fold = []
metrics_per_fold = []
#save the model history in a list after fitting so that we can plot later
initial_training_history = []
fine_tuning_history = []

# %%
def initial_training(img_height, img_width, batch_size, datagen, train_df, val_df, initial_training_history):
    
    # Load this fold's training and validation data using the data generator
    train_data = datagen.flow_from_dataframe(
        train_df,
        x_col='filename',
        y_col='class',
        target_size=(img_height, img_width),
        batch_size=batch_size,
        class_mode='categorical'
    )
    val_data = datagen.flow_from_dataframe(
        val_df,
        x_col='filename',
        y_col='class',
        target_size=(img_height, img_width),
        batch_size=batch_size,
        class_mode='categorical'
    )
    
    base_model = tf.keras.applications.resnet50.ResNet50(
        include_top=False,
        weights='imagenet',
        input_shape=(img_height, img_width,3)
    )
    base_model.trainable = False
    
    image_batch, label_batch = next(iter(train_data))
    feature_batch = base_model(image_batch)
    
    global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
    feature_batch_average = global_average_layer(feature_batch)
    
    prediction_layer = keras.Sequential( [
        tf.keras.layers.Dense(128),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(3)
    ])
    prediction_batch = prediction_layer(feature_batch_average)
    
    preprocess_input = tf.keras.applications.resnet50.preprocess_input
    
    # add classifier head or top
    inputs = tf.keras.Input(shape=(img_height, img_width,3) )
    x = preprocess_input(inputs)
    x = base_model(x, training=False)
    x = global_average_layer(x)
    x = tf.keras.layers.Dropout(0.4)(x)
    outputs = prediction_layer(x)
    model = tf.keras.Model(inputs, outputs)
    
    base_learning_rate = 0.0001
    model.compile(optimizer=tf.keras.optimizers.experimental.Adam(learning_rate=base_learning_rate),
                  loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
                  metrics=['accuracy'])
    
    initial_epochs = 5
    history = model.fit(train_data,
                        epochs=initial_epochs,
                        validation_data=val_data)
    initial_training_history.append(history)
    return model

# %%
def create_model(model):
#     model = keras.models.load_model('/kaggle/input/braincancerclassifiaction-initial-training/BCCv3')
    base_model = model.get_layer(index=3)
    base_model.trainable = True
    # Fine-tune from this layer onwards
    fine_tune_at = 140

    # Freeze all the layers before the `fine_tune_at` layer
    for layer in base_model.layers[:fine_tune_at]:
      layer.trainable = False
    base_learning_rate= 0.0001
    model.compile(loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
                  optimizer = tf.keras.optimizers.RMSprop(learning_rate=base_learning_rate/10),
                  metrics=['accuracy'])
    return model

# %%
def fine_tuning(img_height, img_width, batch_size, datagen, train_df, val_df, model, fine_tuning_history, acc_per_fold):
    # Load this fold's training and validation data using the data generator
    fine_tuning_epoch = 10
    
    train_data = datagen.flow_from_dataframe(
        train_df,
        x_col='filename',
        y_col='class',
        target_size=(img_height, img_width),
        batch_size=batch_size,
        class_mode='categorical'
    )
    val_data = datagen.flow_from_dataframe(
        val_df,
        x_col='filename',
        y_col='class',
        target_size=(img_height, img_width),
        batch_size=batch_size,
        class_mode='categorical'
    )
    
    # Create a new model for each fold within the scope of the TPU strategy
    # with strategy.scope():
    fine_tuning_model = create_model(model)
    
    # Train the model on this fold's training data and evaluate on validation data
    history = fine_tuning_model.fit(train_data, validation_data=val_data, epochs=fine_tuning_epoch)
    fine_tuning_history.append(history)
    
    # Evaluate the model on this fold's validation data
    scores = fine_tuning_model.evaluate(val_data)
    acc_per_fold.append(scores[1])
    return fine_tuning_model

# %%
from sklearn.metrics import (accuracy_score, f1_score, precision_score,
                             recall_score, roc_auc_score,
                             matthews_corrcoef, log_loss, classification_report, 
                             confusion_matrix, cohen_kappa_score,
                             jaccard_score, hamming_loss,
                             balanced_accuracy_score, top_k_accuracy_score)

def calculate_metrics(y_true, y_prob, y_pred):
    metrics = {}
    metrics['accuracy'] = accuracy_score(y_true, y_pred)
    target_names = ['class 1', 'class 2', 'class 3']
    metrics['classification_report'] = classification_report(y_true, y_pred, target_names=target_names)
    metrics['f1_weighted'] = f1_score(y_true, y_pred, average='weighted')
    metrics['f1_macro'] = f1_score(y_true, y_pred, average='macro')
    metrics['f1_micro'] = f1_score(y_true, y_pred, average='micro')
    metrics['precision_weighted'] = precision_score(y_true, y_pred, average='weighted')
    metrics['precision_macro'] = precision_score(y_true, y_pred, average='macro')
    metrics['precision_micro'] = precision_score(y_true, y_pred, average='micro')
    metrics['recall_weighted'] = recall_score(y_true, y_pred, average='weighted')
    metrics['recall_macro'] = recall_score(y_true, y_pred, average='macro')
    metrics['recall_micro'] = recall_score(y_true, y_pred, average='micro')
    metrics['roc_auc_ovr'] = roc_auc_score(y_true, y_prob, multi_class='ovr', average='weighted')
    metrics['roc_auc_ovo'] = roc_auc_score(y_true, y_prob, multi_class='ovo', average='weighted')
    metrics['matthews_corrcoef'] = matthews_corrcoef(y_true, y_pred)
    metrics['log_loss'] = log_loss(y_true, y_prob)
    metrics['confusion_matrix'] = confusion_matrix(y_true, y_pred)
    metrics['cohen_kappa'] = cohen_kappa_score(y_true,y_pred)
    metrics['jaccard_weighted'] = jaccard_score(y_true,y_pred ,average='weighted')
    metrics['jaccard_macro'] = jaccard_score(y_true,y_pred ,average='macro')
    metrics['jaccard_micro'] = jaccard_score(y_true,y_pred ,average='micro')
    metrics['hamming_loss'] = hamming_loss(y_true,y_pred)
    metrics['balanced_accuracy'] = balanced_accuracy_score(y_true,y_pred)
    metrics['top_k_accuracy'] = top_k_accuracy_score(y_true,y_prob)
    
    return metrics

# %%
def prediction_and_analysis(img_height, img_width, batch_size, datagen, val_df, fine_tuned_model):
    val_data = datagen.flow_from_dataframe(
        val_df,
        x_col='filename',
        y_col='class',
        target_size=(img_height, img_width),
        batch_size=batch_size,
        class_mode='categorical'
    )   
    y_true = []
    y_prob = []
    y_pred = []
    for i in range(val_data.samples // batch_size):
        X_val_batch, y_val_batch = next(val_data)
        y_true.append(y_val_batch)
        logits = model.predict(X_val_batch)
        y_prob_batch = tf.nn.softmax(logits)
        y_prob.append(y_prob_batch)
        y_pred_batch = tf.argmax(y_prob_batch, axis=-1)
        y_pred.append(y_pred_batch)

    if val_data.samples % batch_size != 0:
        X_val_batch, y_val_batch = next(val_data)
        y_true.append(y_val_batch[:val_data.samples % batch_size])
        logits = model.predict(X_val_batch[:val_data.samples % batch_size])
        y_prob_batch = tf.nn.softmax(logits)
        y_prob.append(y_prob_batch)
        y_pred_batch = tf.argmax(y_prob_batch, axis=-1)
        y_pred.append(y_pred_batch)

    y_true = np.concatenate(y_true)
    y_true = np.argmax(y_true, axis=-1)
    y_prob = np.concatenate(y_prob)
    y_pred = np.concatenate(y_pred)
    
    return calculate_metrics(y_true, y_prob, y_pred)

# %%
fold = 1
stop_at_fold = 5
for train_index, test_index in kfold.split(df):
    # Print the fold number
    print(f'Fold {fold}/{num_folds}')

    # Get the training and validation data
    train_df = df.iloc[train_index]
    val_df = df.iloc[test_index]
    
    
    # Create a new instance of the model and training it
    model = initial_training(img_height, img_width, batch_size, datagen, train_df, val_df, initial_training_history)
    
    # Fine tuning
    fine_tuned_model = fine_tuning(img_height, img_width, batch_size, datagen, train_df, val_df, model, fine_tuning_history, acc_per_fold)
    
    # Prediction, analysis and metrics
    metrics = prediction_and_analysis(img_height, img_width, batch_size, datagen, val_df, fine_tuned_model)
    metrics_per_fold.append(metrics)
    
    if(fold == stop_at_fold):
        break
        
    fold += 1
# Out:
# Fold 1/5
# Found 9804 validated image filenames belonging to 3 classes.
# Found 2452 validated image filenames belonging to 3 classes.
# Epoch 1/5
# 307/307 [==============================] - 34s 100ms/step - loss: 0.8782 - accuracy: 0.6738 - val_loss: 0.4137 - val_accuracy: 0.8320
# Epoch 2/5
# 307/307 [==============================] - 32s 106ms/step - loss: 0.5152 - accuracy: 0.8007 - val_loss: 0.3577 - val_accuracy: 0.8495
# Epoch 3/5
# 307/307 [==============================] - 31s 100ms/step - loss: 0.4536 - accuracy: 0.8222 - val_loss: 0.3449 - val_accuracy: 0.8662
# Epoch 4/5
# 307/307 [==============================] - 29s 94ms/step - loss: 0.4244 - accuracy: 0.8315 - val_loss: 0.3321 - val_accuracy: 0.8638
# Epoch 5/5
# 307/307 [==============================] - 30s 99ms/step - loss: 0.3994 - accuracy: 0.8424 - val_loss: 0.3258 - val_accuracy: 0.8695
# Found 9804 validated image filenames belonging to 3 classes.
# Found 2452 validated image filenames belonging to 3 classes.
# Epoch 1/10
# 307/307 [==============================] - 42s 109ms/step - loss: 0.2998 - accuracy: 0.8792 - val_loss: 0.2388 - val_accuracy: 0.9038
# Epoch 2/10
# 307/307 [==============================] - 35s 113ms/step - loss: 0.1898 - accuracy: 0.9284 - val_loss: 0.2151 - val_accuracy: 0.9180
# Epoch 3/10
# 307/307 [==============================] - 33s 107ms/step - loss: 0.1150 - accuracy: 0.9565 - val_loss: 0.1922 - val_accuracy: 0.9270
# Epoch 4/10
# 307/307 [==============================] - 33s 107ms/step - loss: 0.0719 - accuracy: 0.9726 - val_loss: 0.2166 - val_accuracy: 0.9327
# Epoch 5/10
# 307/307 [==============================] - 33s 107ms/step - loss: 0.0432 - accuracy: 0.9844 - val_loss: 0.2112 - val_accuracy: 0.9364
# Epoch 6/10
# 307/307 [==============================] - 33s 108ms/step - loss: 0.0254 - accuracy: 0.9912 - val_loss: 0.2003 - val_accuracy: 0.9462
# Epoch 7/10
# 307/307 [==============================] - 32s 104ms/step - loss: 0.0162 - accuracy: 0.9946 - val_loss: 0.2214 - val_accuracy: 0.9454
# Epoch 8/10
# 307/307 [==============================] - 33s 107ms/step - loss: 0.0124 - accuracy: 0.9957 - val_loss: 0.2513 - val_accuracy: 0.9454
# Epoch 9/10
# 307/307 [==============================] - 33s 109ms/step - loss: 0.0071 - accuracy: 0.9976 - val_loss: 0.2491 - val_accuracy: 0.9474
# Epoch 10/10
# 307/307 [==============================] - 34s 109ms/step - loss: 0.0060 - accuracy: 0.9980 - val_loss: 0.2689 - val_accuracy: 0.9462
# 77/77 [==============================] - 6s 80ms/step - loss: 0.2689 - accuracy: 0.9462
# Found 2452 validated image filenames belonging to 3 classes.
# 1/1 [==============================] - 1s 964ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 1s 912ms/step
# Fold 2/5
# Found 9805 validated image filenames belonging to 3 classes.
# Found 2451 validated image filenames belonging to 3 classes.
# Epoch 1/5
# 307/307 [==============================] - 36s 106ms/step - loss: 0.8746 - accuracy: 0.6720 - val_loss: 0.3612 - val_accuracy: 0.8548
# Epoch 2/5
# 307/307 [==============================] - 31s 101ms/step - loss: 0.5438 - accuracy: 0.7890 - val_loss: 0.3303 - val_accuracy: 0.8637
# Epoch 3/5
# 307/307 [==============================] - 30s 97ms/step - loss: 0.4786 - accuracy: 0.8151 - val_loss: 0.2719 - val_accuracy: 0.8866
# Epoch 4/5
# 307/307 [==============================] - 30s 98ms/step - loss: 0.4315 - accuracy: 0.8291 - val_loss: 0.2666 - val_accuracy: 0.8862
# Epoch 5/5
# 307/307 [==============================] - 31s 101ms/step - loss: 0.4194 - accuracy: 0.8364 - val_loss: 0.2475 - val_accuracy: 0.8980
# Found 9805 validated image filenames belonging to 3 classes.
# Found 2451 validated image filenames belonging to 3 classes.
# Epoch 1/10
# 307/307 [==============================] - 40s 108ms/step - loss: 0.3185 - accuracy: 0.8731 - val_loss: 0.1805 - val_accuracy: 0.9257
# Epoch 2/10
# 307/307 [==============================] - 33s 109ms/step - loss: 0.1908 - accuracy: 0.9281 - val_loss: 0.1406 - val_accuracy: 0.9433
# Epoch 3/10
# 307/307 [==============================] - 32s 106ms/step - loss: 0.1206 - accuracy: 0.9538 - val_loss: 0.1473 - val_accuracy: 0.9466
# Epoch 4/10
# 307/307 [==============================] - 33s 107ms/step - loss: 0.0743 - accuracy: 0.9723 - val_loss: 0.1265 - val_accuracy: 0.9539
# Epoch 5/10
# 307/307 [==============================] - 37s 119ms/step - loss: 0.0491 - accuracy: 0.9828 - val_loss: 0.1405 - val_accuracy: 0.9494
# Epoch 6/10
# 307/307 [==============================] - 33s 107ms/step - loss: 0.0296 - accuracy: 0.9905 - val_loss: 0.1459 - val_accuracy: 0.9535
# Epoch 7/10
# 307/307 [==============================] - 33s 108ms/step - loss: 0.0208 - accuracy: 0.9924 - val_loss: 0.1510 - val_accuracy: 0.9563
# Epoch 8/10
# 307/307 [==============================] - 33s 106ms/step - loss: 0.0120 - accuracy: 0.9957 - val_loss: 0.1389 - val_accuracy: 0.9670
# Epoch 9/10
# 307/307 [==============================] - 32s 105ms/step - loss: 0.0073 - accuracy: 0.9972 - val_loss: 0.2202 - val_accuracy: 0.9506
# Epoch 10/10
# 307/307 [==============================] - 33s 107ms/step - loss: 0.0070 - accuracy: 0.9979 - val_loss: 0.1663 - val_accuracy: 0.9649
# 77/77 [==============================] - 6s 82ms/step - loss: 0.1663 - accuracy: 0.9649
# Found 2451 validated image filenames belonging to 3 classes.
# 1/1 [==============================] - 1s 883ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 1s 940ms/step
# Fold 3/5
# Found 9805 validated image filenames belonging to 3 classes.
# Found 2451 validated image filenames belonging to 3 classes.
# Epoch 1/5
# 307/307 [==============================] - 36s 106ms/step - loss: 0.8734 - accuracy: 0.6782 - val_loss: 0.3761 - val_accuracy: 0.8572
# Epoch 2/5
# 307/307 [==============================] - 31s 102ms/step - loss: 0.5309 - accuracy: 0.7950 - val_loss: 0.3387 - val_accuracy: 0.8662
# Epoch 3/5
# 307/307 [==============================] - 31s 100ms/step - loss: 0.4560 - accuracy: 0.8189 - val_loss: 0.2928 - val_accuracy: 0.8874
# Epoch 4/5
# 307/307 [==============================] - 30s 99ms/step - loss: 0.4382 - accuracy: 0.8313 - val_loss: 0.2885 - val_accuracy: 0.8874
# Epoch 5/5
# 307/307 [==============================] - 30s 97ms/step - loss: 0.4093 - accuracy: 0.8441 - val_loss: 0.2664 - val_accuracy: 0.8996
# Found 9805 validated image filenames belonging to 3 classes.
# Found 2451 validated image filenames belonging to 3 classes.
# Epoch 1/10
# 307/307 [==============================] - 41s 108ms/step - loss: 0.3071 - accuracy: 0.8794 - val_loss: 0.2062 - val_accuracy: 0.9164
# Epoch 2/10
# 307/307 [==============================] - 33s 106ms/step - loss: 0.1948 - accuracy: 0.9200 - val_loss: 0.1709 - val_accuracy: 0.9347
# Epoch 3/10
# 307/307 [==============================] - 32s 105ms/step - loss: 0.1188 - accuracy: 0.9537 - val_loss: 0.1631 - val_accuracy: 0.9392
# Epoch 4/10
# 307/307 [==============================] - 32s 106ms/step - loss: 0.0765 - accuracy: 0.9705 - val_loss: 0.1615 - val_accuracy: 0.9449
# Epoch 5/10
# 307/307 [==============================] - 32s 105ms/step - loss: 0.0462 - accuracy: 0.9832 - val_loss: 0.1730 - val_accuracy: 0.9486
# Epoch 6/10
# 307/307 [==============================] - 32s 103ms/step - loss: 0.0275 - accuracy: 0.9908 - val_loss: 0.2320 - val_accuracy: 0.9457
# Epoch 7/10
# 307/307 [==============================] - 32s 104ms/step - loss: 0.0179 - accuracy: 0.9936 - val_loss: 0.2353 - val_accuracy: 0.9478
# Epoch 8/10
# 307/307 [==============================] - 32s 104ms/step - loss: 0.0137 - accuracy: 0.9940 - val_loss: 0.1916 - val_accuracy: 0.9527
# Epoch 9/10
# 307/307 [==============================] - 33s 107ms/step - loss: 0.0105 - accuracy: 0.9968 - val_loss: 0.1954 - val_accuracy: 0.9543
# Epoch 10/10
# 307/307 [==============================] - 32s 104ms/step - loss: 0.0065 - accuracy: 0.9975 - val_loss: 0.2319 - val_accuracy: 0.9551
# 77/77 [==============================] - 6s 76ms/step - loss: 0.2319 - accuracy: 0.9551
# Found 2451 validated image filenames belonging to 3 classes.
# 1/1 [==============================] - 1s 896ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 1s 909ms/step
# Fold 4/5
# Found 9805 validated image filenames belonging to 3 classes.
# Found 2451 validated image filenames belonging to 3 classes.
# Epoch 1/5
# 307/307 [==============================] - 37s 108ms/step - loss: 0.8523 - accuracy: 0.6875 - val_loss: 0.3973 - val_accuracy: 0.8388
# Epoch 2/5
# 307/307 [==============================] - 32s 103ms/step - loss: 0.5222 - accuracy: 0.8031 - val_loss: 0.3492 - val_accuracy: 0.8629
# Epoch 3/5
# 307/307 [==============================] - 29s 95ms/step - loss: 0.4563 - accuracy: 0.8269 - val_loss: 0.3136 - val_accuracy: 0.8719
# Epoch 4/5
# 307/307 [==============================] - 29s 94ms/step - loss: 0.4230 - accuracy: 0.8362 - val_loss: 0.3045 - val_accuracy: 0.8792
# Epoch 5/5
# 307/307 [==============================] - 29s 96ms/step - loss: 0.4040 - accuracy: 0.8411 - val_loss: 0.2954 - val_accuracy: 0.8845
# Found 9805 validated image filenames belonging to 3 classes.
# Found 2451 validated image filenames belonging to 3 classes.
# Epoch 1/10
# 307/307 [==============================] - 41s 109ms/step - loss: 0.3061 - accuracy: 0.8801 - val_loss: 0.2276 - val_accuracy: 0.9143
# Epoch 2/10
# 307/307 [==============================] - 33s 107ms/step - loss: 0.1918 - accuracy: 0.9251 - val_loss: 0.1883 - val_accuracy: 0.9298
# Epoch 3/10
# 307/307 [==============================] - 33s 108ms/step - loss: 0.1214 - accuracy: 0.9541 - val_loss: 0.1761 - val_accuracy: 0.9274
# Epoch 4/10
# 307/307 [==============================] - 32s 106ms/step - loss: 0.0784 - accuracy: 0.9714 - val_loss: 0.1687 - val_accuracy: 0.9392
# Epoch 5/10
# 307/307 [==============================] - 38s 122ms/step - loss: 0.0487 - accuracy: 0.9834 - val_loss: 0.1753 - val_accuracy: 0.9400
# Epoch 6/10
# 307/307 [==============================] - 34s 110ms/step - loss: 0.0282 - accuracy: 0.9907 - val_loss: 0.1661 - val_accuracy: 0.9498
# Epoch 7/10
# 307/307 [==============================] - 32s 106ms/step - loss: 0.0181 - accuracy: 0.9937 - val_loss: 0.1752 - val_accuracy: 0.9449
# Epoch 8/10
# 307/307 [==============================] - 32s 104ms/step - loss: 0.0108 - accuracy: 0.9965 - val_loss: 0.1954 - val_accuracy: 0.9486
# Epoch 9/10
# 307/307 [==============================] - 33s 107ms/step - loss: 0.0103 - accuracy: 0.9970 - val_loss: 0.2078 - val_accuracy: 0.9502
# Epoch 10/10
# 307/307 [==============================] - 32s 104ms/step - loss: 0.0062 - accuracy: 0.9976 - val_loss: 0.3205 - val_accuracy: 0.9355
# 77/77 [==============================] - 6s 73ms/step - loss: 0.3205 - accuracy: 0.9355
# Found 2451 validated image filenames belonging to 3 classes.
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 1s 910ms/step
# Fold 5/5
# Found 9805 validated image filenames belonging to 3 classes.
# Found 2451 validated image filenames belonging to 3 classes.
# Epoch 1/5
# 307/307 [==============================] - 35s 103ms/step - loss: 0.8285 - accuracy: 0.6855 - val_loss: 0.3540 - val_accuracy: 0.8531
# Epoch 2/5
# 307/307 [==============================] - 29s 93ms/step - loss: 0.5464 - accuracy: 0.7874 - val_loss: 0.3275 - val_accuracy: 0.8715
# Epoch 3/5
# 307/307 [==============================] - 30s 97ms/step - loss: 0.4712 - accuracy: 0.8181 - val_loss: 0.2861 - val_accuracy: 0.8849
# Epoch 4/5
# 307/307 [==============================] - 31s 99ms/step - loss: 0.4370 - accuracy: 0.8331 - val_loss: 0.2830 - val_accuracy: 0.8882
# Epoch 5/5
# 307/307 [==============================] - 29s 94ms/step - loss: 0.4224 - accuracy: 0.8314 - val_loss: 0.2626 - val_accuracy: 0.8927
# Found 9805 validated image filenames belonging to 3 classes.
# Found 2451 validated image filenames belonging to 3 classes.
# Epoch 1/10
# 307/307 [==============================] - 40s 109ms/step - loss: 0.3186 - accuracy: 0.8755 - val_loss: 0.2125 - val_accuracy: 0.9155
# Epoch 2/10
# 307/307 [==============================] - 33s 108ms/step - loss: 0.1898 - accuracy: 0.9284 - val_loss: 0.1626 - val_accuracy: 0.9359
# Epoch 3/10
# 307/307 [==============================] - 32s 105ms/step - loss: 0.1220 - accuracy: 0.9517 - val_loss: 0.1919 - val_accuracy: 0.9343
# Epoch 4/10
# 307/307 [==============================] - 33s 107ms/step - loss: 0.0733 - accuracy: 0.9704 - val_loss: 0.1643 - val_accuracy: 0.9474
# Epoch 5/10
# 307/307 [==============================] - 32s 105ms/step - loss: 0.0456 - accuracy: 0.9841 - val_loss: 0.1613 - val_accuracy: 0.9539
# Epoch 6/10
# 307/307 [==============================] - 33s 107ms/step - loss: 0.0276 - accuracy: 0.9901 - val_loss: 0.2287 - val_accuracy: 0.9457
# Epoch 7/10
# 307/307 [==============================] - 32s 105ms/step - loss: 0.0174 - accuracy: 0.9935 - val_loss: 0.1828 - val_accuracy: 0.9547
# Epoch 8/10
# 307/307 [==============================] - 32s 104ms/step - loss: 0.0122 - accuracy: 0.9960 - val_loss: 0.2114 - val_accuracy: 0.9572
# Epoch 9/10
# 307/307 [==============================] - 32s 104ms/step - loss: 0.0095 - accuracy: 0.9965 - val_loss: 0.2879 - val_accuracy: 0.9412
# Epoch 10/10
# 307/307 [==============================] - 32s 105ms/step - loss: 0.0072 - accuracy: 0.9978 - val_loss: 0.2280 - val_accuracy: 0.9584
# 77/77 [==============================] - 6s 76ms/step - loss: 0.2280 - accuracy: 0.9584
# Found 2451 validated image filenames belonging to 3 classes.
# 1/1 [==============================] - 1s 984ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 1s 911ms/step

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

# Plot the initial history on the left subplot
ax1.set_title('Initial Training Accuracies vs Epochs')
label_name = ''
for i in range(min(fold, num_folds)):
    label_name = 'Training Fold ' + str(i+1)
    ax1.plot(initial_training_history[i].history['accuracy'], label=label_name)
ax1.legend()

# Plot the fine-tuning history on the right subplot
ax2.set_title('Fine-tuning Training Accuracies vs Epochs')
label_name = ''
for i in range(min(fold, num_folds)):
    label_name = 'Training Fold ' + str(i+1)
    ax2.plot(fine_tuning_history[i].history['accuracy'], label=label_name)
ax2.legend()

plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

# Plot the initial history on the left subplot
ax1.set_title('Initial Training Accuracies vs Epochs')
label_name = ''
for i in range(min(fold, num_folds)):
    label_name = 'Training Fold ' + str(i+1)
    ax1.plot(initial_training_history[i].history['val_accuracy'], label=label_name)
ax1.legend()

# Plot the fine-tuning history on the right subplot
ax2.set_title('Fine-tuning Training Accuracies vs Epochs')
label_name = ''
for i in range(min(fold, num_folds)):
    label_name = 'Training Fold ' + str(i+1)
    ax2.plot(fine_tuning_history[i].history['val_accuracy'], label=label_name)
ax2.legend()

plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

# Plot the initial history on the left subplot
ax1.set_title('Initial Training Accuracy vs Validation Accuracy')
train_label = '' 
val_label = ''
colors = ['blue', 'green', 'yellow', 'orange', 'red', 'black']
for i in range(min(fold, num_folds)):
    train_label = 'Training Accuracy Fold ' + str(i+1)
    val_label = 'Validation Accuracy Fold ' + str(i+1)
    ax1.plot(initial_training_history[i].history['accuracy'], label=train_label, color=colors[i])
    ax1.plot(initial_training_history[i].history['val_accuracy'], label=val_label, color=colors[i], linestyle = "dashdot")
ax1.legend()

# Plot the fine-tuning history on the right subplot
ax2.set_title('Fine-tuning Training Accuracy vs Validation Accuracy')
train_label = '' 
val_label = ''
colors = ['blue', 'green', 'yellow', 'orange', 'red', 'black']
for i in range(min(fold, num_folds)):
    train_label = 'Training Accuracy Fold ' + str(i+1)
    val_label = 'Validation Accuracy Fold ' + str(i+1)
    ax2.plot(fine_tuning_history[i].history['accuracy'], label=train_label, color=colors[i])
    ax2.plot(fine_tuning_history[i].history['val_accuracy'], label=val_label, color=colors[i], linestyle = "dashdot")
ax2.legend()

plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

# Plot the initial history on the left subplot
ax1.set_title('Initial Training Losses vs Epochs')
label_name = ''
for i in range(min(fold, num_folds)):
    label_name = 'Training Fold ' + str(i+1)
    ax1.plot(initial_training_history[i].history['loss'], label=label_name)
ax1.legend()

# Plot the fine-tuning history on the right subplot
ax2.set_title('Fine-tuning Training Losses vs Epochs')
label_name = ''
for i in range(min(fold, num_folds)):
    label_name = 'Training Fold ' + str(i+1)
    ax2.plot(fine_tuning_history[i].history['loss'], label=label_name)
ax2.legend()

plt.show()

# %%
# plt.title('Losses vs Epochs')
# label_name = ''
# for i in range(min(fold, num_folds)):
#     label_name = 'Validation Fold ' + str(i+1)
#     plt.plot(fine_tuning_history[i].history['val_loss'], label=label_name)
# plt.legend()
# plt.show()
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

# Plot the initial history on the left subplot
ax1.set_title('Initial Validation Losses vs Epochs')
label_name = ''
for i in range(min(fold, num_folds)):
    label_name = 'Validation Fold ' + str(i+1)
    ax1.plot(initial_training_history[i].history['val_loss'], label=label_name)
ax1.legend()

# Plot the fine-tuning history on the right subplot
ax2.set_title('Fine-tuning Validation Losses vs Epochs')
label_name = ''
for i in range(min(fold, num_folds)):
    label_name = 'Validation Fold ' + str(i+1)
    ax2.plot(fine_tuning_history[i].history['val_loss'], label=label_name)
ax2.legend()

plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

# Plot the initial history on the left subplot
ax1.set_title('Initial Training Loss vs Validation Loss')
train_label = '' 
val_label = ''
colors = ['blue', 'green', 'yellow', 'orange', 'red', 'black']
for i in range(min(fold, num_folds)):
    train_label = 'Training Loss Fold ' + str(i+1)
    val_label = 'Validation Loss Fold ' + str(i+1)
    ax1.plot(initial_training_history[i].history['loss'], label=train_label, color=colors[i])
    ax1.plot(initial_training_history[i].history['val_loss'], label=val_label, color=colors[i], linestyle = "dashdot")
ax1.legend()

# Plot the fine-tuning history on the right subplot
ax2.set_title('Fine-tuning Training Loss vs Validation Loss')
train_label = '' 
val_label = ''
colors = ['blue', 'green', 'yellow', 'orange', 'red', 'black']
for i in range(min(fold, num_folds)):
    train_label = 'Training Loss Fold ' + str(i+1)
    val_label = 'Validation Loss Fold ' + str(i+1)
    ax2.plot(fine_tuning_history[i].history['loss'], label=train_label, color=colors[i])
    ax2.plot(fine_tuning_history[i].history['val_loss'], label=val_label, color=colors[i], linestyle = "dashdot")
ax2.legend()

plt.show()

# %%
# Print the average accuracy across all folds
print(f'Average accuracy: {np.mean(acc_per_fold)}')
print(f'Standard deviation in accuracy: {np.std(acc_per_fold)}')
# Out:
# Average accuracy: 0.952023983001709
# Standard deviation in accuracy: 0.010220554495660675

# %%
def display_confusion_matrices(metrics_list, class_labels, k=5):
    n_models = min(k, len(metrics_list))
    
    if n_models == 1:
        fig, ax = plt.subplots(1, n_models, figsize=(5 * n_models, 5))
        axes = [ax]
    else:
        fig, axes = plt.subplots(1, n_models, figsize=(5 * n_models, 5))
    
    for i in range(n_models):
        metrics = metrics_list[i]
        confusion_matrix = metrics['confusion_matrix']
        sns.heatmap(confusion_matrix, annot=True, fmt='d', xticklabels=class_labels, yticklabels=class_labels, ax=axes[i])
        axes[i].set_xlabel('Predicted label')
        axes[i].set_ylabel('True label')
        axes[i].set_title(f'Model {i+1}')
    
    plt.show()
    
    return
    
class_labels = ['class 1', 'class 2', 'class 3']
display_confusion_matrices(metrics_per_fold, class_labels)

# %%
def print_metrics_per_fold(metrics_per_fold):
    for i, metrics in enumerate(metrics_per_fold):
        print(f'Fold {i+1}:')
        for metric_name, metric_value in metrics.items():
            if(metric_name == 'classification_report' or metric_name == 'confusion_matrix'):
                print(f'  {metric_name}:')
                print(f'  {metric_value}')
            else:
                print(f'  {metric_name}: {metric_value}')

    return
print_metrics_per_fold(metrics_per_fold)
# Out:
# Fold 1:
#   accuracy: 0.9461663947797716
#   classification_report:
#                 precision    recall  f1-score   support
#
#      class 1       0.91      0.88      0.90       607
#      class 2       0.96      0.96      0.96      1138
#      class 3       0.94      0.98      0.96       707
#
#     accuracy                           0.95      2452
#    macro avg       0.94      0.94      0.94      2452
# weighted avg       0.95      0.95      0.95      2452
#
#   f1_weighted: 0.9458670505661736
#   f1_macro: 0.9405712911698143
#   f1_micro: 0.9461663947797716
#   precision_weighted: 0.9459889965369547
#   precision_macro: 0.940729920573944
#   precision_micro: 0.9461663947797716
#   recall_weighted: 0.9461663947797716
#   recall_macro: 0.9409223866042117
#   recall_micro: 0.9461663947797716
#   roc_auc_ovr: 0.9941125501867902
#   roc_auc_ovo: 0.9936874729486862
#   matthews_corrcoef: 0.9161269785255468
#   log_loss: 0.2688730847534704
#   confusion_matrix:
#   [[ 535   37   35]
#  [  42 1089    7]
#  [   8    3  696]]
#   cohen_kappa: 0.9159454231126714
#   jaccard_weighted: 0.898563891116219
#   jaccard_macro: 0.8893315535914379
#   jaccard_micro: 0.8978328173374613
#   hamming_loss: 0.053833605220228384
#   balanced_accuracy: 0.9409223866042117
#   top_k_accuracy: 0.9967373572593801
# Fold 2:
#   accuracy: 0.9649122807017544
#   classification_report:
#                 precision    recall  f1-score   support
#
#      class 1       0.94      0.91      0.93       558
#      class 2       0.97      0.98      0.97      1115
#      class 3       0.98      0.99      0.98       778
#
#     accuracy                           0.96      2451
#    macro avg       0.96      0.96      0.96      2451
# weighted avg       0.96      0.96      0.96      2451
#
#   f1_weighted: 0.9646971022176604
#   f1_macro: 0.9599477217862341
#   f1_micro: 0.9649122807017544
#   precision_weighted: 0.9646830121329407
#   precision_macro: 0.9623870807063738
#   precision_micro: 0.9649122807017544
#   recall_weighted: 0.9649122807017544
#   recall_macro: 0.9577757184789798
#   recall_micro: 0.9649122807017544
#   roc_auc_ovr: 0.9963094802713006
#   roc_auc_ovo: 0.9957632386000518
#   matthews_corrcoef: 0.9451761535431694
#   log_loss: 0.16634195590798972
#   confusion_matrix:
#   [[ 507   34   17]
#  [  23 1090    2]
#  [   7    3  768]]
#   cohen_kappa: 0.945091568755757
#   jaccard_weighted: 0.9326051876948892
#   jaccard_macro: 0.9240130014434325
#   jaccard_micro: 0.9322033898305084
#   hamming_loss: 0.03508771929824561
#   balanced_accuracy: 0.9577757184789798
#   top_k_accuracy: 0.9991840065279478
# Fold 3:
#   accuracy: 0.9551203590371277
#   classification_report:
#                 precision    recall  f1-score   support
#
#      class 1       0.91      0.91      0.91       556
#      class 2       0.97      0.96      0.97      1131
#      class 3       0.96      0.98      0.97       764
#
#     accuracy                           0.96      2451
#    macro avg       0.95      0.95      0.95      2451
# weighted avg       0.96      0.96      0.96      2451
#
#   f1_weighted: 0.9551456983079295
#   f1_macro: 0.9490892537339519
#   f1_micro: 0.9551203590371277
#   precision_weighted: 0.9552623932088469
#   precision_macro: 0.9478815794177146
#   precision_micro: 0.9551203590371277
#   recall_weighted: 0.9551203590371277
#   recall_macro: 0.9503800989372236
#   recall_micro: 0.9551203590371277
#   roc_auc_ovr: 0.9946864864677659
#   roc_auc_ovo: 0.9938164756574751
#   matthews_corrcoef: 0.9298776218629093
#   log_loss: 0.23191276697437174
#   confusion_matrix:
#   [[ 507   27   22]
#  [  38 1086    7]
#  [  14    2  748]]
#   cohen_kappa: 0.9298238581703239
#   jaccard_weighted: 0.915191271859352
#   jaccard_macro: 0.9044473144475749
#   jaccard_micro: 0.9140960562280359
#   hamming_loss: 0.044879640962872294
#   balanced_accuracy: 0.9503800989372236
#   top_k_accuracy: 0.996328029375765
# Fold 4:
#   accuracy: 0.9355365157078743
#   classification_report:
#                 precision    recall  f1-score   support
#
#      class 1       0.84      0.93      0.89       573
#      class 2       0.99      0.91      0.95      1158
#      class 3       0.94      0.97      0.96       720
#
#     accuracy                           0.94      2451
#    macro avg       0.92      0.94      0.93      2451
# weighted avg       0.94      0.94      0.94      2451
#
#   f1_weighted: 0.9362851167633173
#   f1_macro: 0.9301845352851043
#   f1_micro: 0.9355365157078743
#   precision_weighted: 0.9395287283947208
#   precision_macro: 0.9233838936273098
#   precision_micro: 0.9355365157078743
#   recall_weighted: 0.9355365157078743
#   recall_macro: 0.9395557223392723
#   recall_micro: 0.9355365157078743
#   roc_auc_ovr: 0.994918772855412
#   roc_auc_ovo: 0.9943272941041692
#   matthews_corrcoef: 0.9012072771790396
#   log_loss: 0.32047302743360934
#   confusion_matrix:
#   [[ 534   11   28]
#  [  82 1059   17]
#  [  17    3  700]]
#   cohen_kappa: 0.8998235274944785
#   jaccard_weighted: 0.8814784642619982
#   jaccard_macro: 0.8710863848762864
#   jaccard_micro: 0.878880797240322
#   hamming_loss: 0.06446348429212566
#   balanced_accuracy: 0.9395557223392723
#   top_k_accuracy: 0.9918400652794778
# Fold 5:
#   accuracy: 0.9583843329253366
#   classification_report:
#                 precision    recall  f1-score   support
#
#      class 1       0.91      0.91      0.91       538
#      class 2       0.98      0.97      0.97      1162
#      class 3       0.97      0.98      0.97       751
#
#     accuracy                           0.96      2451
#    macro avg       0.95      0.95      0.95      2451
# weighted avg       0.96      0.96      0.96      2451
#
#   f1_weighted: 0.9584092797259773
#   f1_macro: 0.9517134572081263
#   f1_micro: 0.9583843329253366
#   precision_weighted: 0.958469509187273
#   precision_macro: 0.950849985360855
#   precision_micro: 0.9583843329253366
#   recall_weighted: 0.9583843329253366
#   recall_macro: 0.9526092870441908
#   recall_micro: 0.9583843329253366
#   roc_auc_ovr: 0.995020030635815
#   roc_auc_ovo: 0.9940863870198658
#   matthews_corrcoef: 0.9343737379909429
#   log_loss: 0.22801189086217874
#   confusion_matrix:
#   [[ 492   24   22]
#  [  34 1124    4]
#  [  14    4  733]]
#   cohen_kappa: 0.9343524896487834
#   jaccard_weighted: 0.9211444020203474
#   jaccard_macro: 0.9091667340613334
#   jaccard_micro: 0.9200940070505288
#   hamming_loss: 0.0416156670746634
#   balanced_accuracy: 0.9526092870441908
#   top_k_accuracy: 0.9975520195838433
